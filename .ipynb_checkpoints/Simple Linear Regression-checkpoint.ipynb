# %% [markdown]
# # Simple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df = pd.read_csv('height-weight.csv')

# %%
df
# Out:
#     Weight  Height
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160
# 5       78     162
# 6       80     163
# 7       90     175
# 8       95     182
# 9       78     170
# 10      82     176
# 11      95     182
# 12     105     175
# 13     100     183
# 14      85     170
# 15      78     177
# 16      50     140
# 17      65     159
# 18      76     150
# 19      87     167
# 20      45     129
# 21      56     140
# 22      72     160

# %%
plt.scatter(data=df, x='Weight', y = 'Height')
plt.xlabel('Weight', weight = 'bold')
plt.ylabel('Height', weight = 'bold')
plt.title('Height Vs Weight', weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Height Vs Weight')

# %%
X, y  = df[['Weight']], df['Height']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

regression = LinearRegression()

regression = regression.fit(X_train, y_train)

y_train_pred = regression.predict(X_train)

y_test_pred = regression.predict(X_test)


n_train = X_train.shape[0]
n_test = X_test.shape[0]
p = X_train.shape[1]


adj_r2_train = 1 - ((1 - r2_score(y_train, y_train_pred)) * (n_train-1)) / (n_train - p - 1)

adj_r2_test = 1 - ((1 - r2_score(y_test, y_test_pred)) * (n_test-1)) / (n_test - p - 1)


print("Train Data Set  : \n")
print(f'Equation of Line : y_train_pred =  {regression.intercept_} + {round(regression.coef_[0], 2)} X_train')
print(f"Mean Squared Error of linear regression for train dataset: {mean_squared_error(y_train, y_train_pred)}")
print(f"Mean Absolute Error of linear regression for train dataset: {mean_absolute_error(y_train, y_train_pred)}")
print(f"Root Mean Squared Error of linear regression for train dataset: {np.sqrt(mean_absolute_error(y_train, y_train_pred))}")
print(f"r2 score of train dataset : {r2_score(y_train, y_train_pred)}")
print(f"Adjusted R Square train dataset : {adj_r2_train}")

plt.scatter(X_train, y_train)
plt.plot(X_train, y_train_pred, 'r')
plt.show()




print("-" *100)
print("Test Data Set  : \n")
print(f'Equation of Line : y_test_pred =  {regression.intercept_} + {round(regression.coef_[0], 2)} X_test')
print(f"Mean Squared Error of linear regression for test dataset: {mean_squared_error(y_test, y_test_pred)}")
print(f"Mean Absolute Error of linear regression for test dataset: {mean_absolute_error(y_test, y_test_pred)}")
print(f"Root Mean Squared Error of linear regression for test dataset: {np.sqrt(mean_absolute_error(y_test, y_test_pred))}")
print(f"r2 score of test dataset : {r2_score(y_test, y_test_pred)}")
print(f"Adjusted R Square test dataset : {adj_r2_test}")

plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'r')
# Out:
# Train Data Set  :
#
# Equation of Line : y_train_pred =  157.5 + 17.03 X_train
# Mean Squared Error of linear regression for train dataset: 34.74558625746856
# Mean Absolute Error of linear regression for train dataset: 4.48105984626025
# Root Mean Squared Error of linear regression for train dataset: 2.1168513991917925
# r2 score of train dataset : 0.8930630841011483
# Adjusted R Square train dataset : 0.8863795268574701
# ----------------------------------------------------------------------------------------------------
# Test Data Set  :
#
# Equation of Line : y_test_pred =  157.5 + 17.03 X_test
# Mean Squared Error of linear regression for test dataset: 109.77592599051654
# Mean Absolute Error of linear regression for test dataset: 9.822657814519227
# Root Mean Squared Error of linear regression for test dataset: 3.134111965855596
# r2 score of test dataset : 0.7769869860423441
# Adjusted R Square test dataset : 0.7026493147231254

# %%
regression.predict(scaler.transform([[80]]))
# Out:
# array([163.01076266])

# %% [markdown]
# # Assumptions

# %%
plt.scatter(y_test, y_test_pred)

# %%
plt.scatter(y_train, y_train_pred)

# %% [markdown]
# ##### There is a linear relationship between the independent and dependent Features

# %%
residuals = y_test_pred - y_test

sns.displot(residuals, kind='kde')

# %% [markdown]
# ##### Residuals are normally distributed

# %%
plt.scatter(residuals, y_test_pred)

# %% [markdown]
# ##### There is a constant variance in the residuals
