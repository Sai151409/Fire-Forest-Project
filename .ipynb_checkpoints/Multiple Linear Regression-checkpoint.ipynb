# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
califorina = fetch_california_housing()

# %%
X = pd.DataFrame(data = califorina.data, columns=califorina['feature_names'])

# %%
y = pd.DataFrame(data=califorina['target'], columns=['Price'])

# %%
df = pd.concat([X,y], axis = 1)

# %%
df1 = df.copy()

# %%
df1
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
print(f'The No of null values in the dataset : ')
print(df1.isnull().sum())
print("\n")
print(f'Duplicate values : {df1.duplicated().sum()}')
# Out:
# The No of null values in the dataset :
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# Price         0
# dtype: int64
#
#
# Duplicate values : 0

# %% [markdown]
# ##### There is no null and duplicate values in the dataset

# %%
plt.figure(figsize=(20, 8))

sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=10)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

regression = LinearRegression()

regression = regression.fit(X_train, y_train)

y_train_pred = regression.predict(X_train)

y_test_pred = regression.predict(X_test)

n_train = X_train.shape[0]
n_test = X_test.shape[0]
p = X_train.shape[1]


adj_r2_train = 1 - ((1 - r2_score(y_train, y_train_pred)) * (n_train-1)) / (n_train - p - 1)

adj_r2_test = 1 - ((1 - r2_score(y_test, y_test_pred)) * (n_test-1)) / (n_test - p - 1)


print("Train Data Set  : \n")
print(f"Mean Squared Error of linear regression for train dataset: {mean_squared_error(y_train, y_train_pred)}")
print(f"Mean Absolute Error of linear regression for train dataset: {mean_absolute_error(y_train, y_train_pred)}")
print(f"Root Mean Squared Error of linear regression for train dataset: {np.sqrt(mean_absolute_error(y_train, y_train_pred))}")
print(f"r2 score of train dataset : {r2_score(y_train, y_train_pred)}")
print(f"Adjusted R Square train dataset : {adj_r2_train}")
print("-" *100)
print("Test Data Set  : \n")
print(f"Mean Squared Error of linear regression for test dataset: {mean_squared_error(y_test, y_test_pred)}")
print(f"Mean Absolute Error of linear regression for test dataset: {mean_absolute_error(y_test, y_test_pred)}")
print(f"Root Mean Squared Error of linear regression for test dataset: {np.sqrt(mean_absolute_error(y_test, y_test_pred))}")
print(f"r2 score of test dataset : {r2_score(y_test, y_test_pred)}")
print(f"Adjusted R Square test dataset : {adj_r2_test}")
# Out:
# Train Data Set  :
#
# Mean Squared Error of linear regression for train dataset: 0.5131000770553342
# Mean Absolute Error of linear regression for train dataset: 0.5272495380857498
# Root Mean Squared Error of linear regression for train dataset: 0.7261195067519877
# r2 score of train dataset : 0.6107081709724276
# Adjusted R Square train dataset : 0.6104828048365117
# ----------------------------------------------------------------------------------------------------
# Test Data Set  :
#
# Mean Squared Error of linear regression for test dataset: 0.552233239936362
# Mean Absolute Error of linear regression for test dataset: 0.5371056943007959
# Root Mean Squared Error of linear regression for test dataset: 0.7328749513394464
# r2 score of test dataset : 0.5935958526436639
# Adjusted R Square test dataset : 0.5931179409607519

# %% [markdown]
# # Assumptions

# %%
plt.scatter(y_test, y_test_pred)

# %%
plt.scatter(y_train, y_train_pred)

# %%
residuals = y_test - y_test_pred

sns.displot(residuals, kind='kde')

# %%
plt.scatter(residuals, y_test_pred)
